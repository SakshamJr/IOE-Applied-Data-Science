# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

x=np.array(['Q1','Q2','Q3','Q4'])
y=np.random.randint(10,100,4)
plt.bar(x,y,color='blue', edgecolor='black')
plt.show()

# %%
data = np.random.randn(1000)

# Create histogram
plt.hist(data, bins=100, color='red', edgecolor='black')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')

# Show plot
plt.show()

# %%
x = np.linspace(0,10,100)
y=np.sin(x)
z = np.cos(x)
plt.plot(x,y,color='orange',linewidth=2)
plt.plot(x,z,color='blue',linewidth=2)
plt.show()

# %%
x=np.random.randn(1000)
y=np.random.randn(1000)
plt.scatter(x,y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Scatter Plot")
plt.show()

# %%
fig,axes=plt.subplots(nrows=2,ncols=2,figsize=(6,6))

# (0,0)
c = np.random.randn(10000)
axes[0,0].hist(c,bins=100)
# Out:
# (array([  2.,   0.,   2.,   0.,   1.,   0.,   4.,   2.,   3.,   6.,   3.,
#          10.,   8.,   4.,   8.,  13.,  11.,  23.,  23.,  32.,  29.,  53.,
#          43.,  61.,  63.,  66.,  92., 101.,  82., 104., 130., 147., 168.,
#         159., 171., 192., 213., 243., 226., 232., 275., 261., 275., 273.,
#         292., 299., 307., 302., 312., 324., 292., 326., 285., 302., 275.,
#         257., 241., 220., 226., 204., 181., 173., 183., 152., 135., 125.,
#         114.,  92.,  70.,  74.,  63.,  56.,  42.,  45.,  36.,  20.,  25.,
#          24.,  22.,  13.,  15.,  12.,   9.,   5.,   7.,   5.,   4.,   4.,
#           5.,   3.,   1.,   2.,   0.,   0.,   0.,   1.,   2.,   0.,   0.,
#           2.]),
#  array([-3.61616474, -3.54032467, -3.46448461, -3.38864454, -3.31280448,
#         -3.23696442, -3.16112435, -3.08528429, -3.00944422, -2.93360416,
#         -2.85776409, -2.78192403, -2.70608397, -2.6302439 , -2.55440384,
#         -2.47856377, -2.40272371, -2.32688364, -2.25104358, -2.17520351,
#         -2.09936345, -2.02352339, -1.94768332, -1.87184326, -1.79600319,
#         -1.72016313, -1.64432306, -1.568483  , -1.49264294, -1.41680287,
#         -1.34096281, -1.26512274, -1.18928268, -1.11344261, -1.03760255,
#         -0.96176249, -0.88592242, -0.81008236, -0.73424229, -0.65840223,
#         -0.58256216, -0.5067221 , -0.43088204, -0.35504197, -0.27920191,
#         -0.20336184, -0.12752178, -0.05168171,  0.02415835,  0.09999842,
#          0.17583848,  0.25167854,  0.32751861,  0.40335867,  0.47919874,
#          0.5550388 ,  0.63087887,  0.70671893,  0.78255899,  0.85839906,
#          0.93423912,  1.01007919,  1.08591925,  1.16175932,  1.23759938,
#          1.31343944,  1.38927951,  1.46511957,  1.54095964,  1.6167997 ,
#          1.69263977,  1.76847983,  1.8443199 ,  1.92015996,  1.99600002,
#          2.07184009,  2.14768015,  2.22352022,  2.29936028,  2.37520035,
#          2.45104041,  2.52688047,  2.60272054,  2.6785606 ,  2.75440067,
#          2.83024073,  2.9060808 ,  2.98192086,  3.05776092,  3.13360099,
#          3.20944105,  3.28528112,  3.36112118,  3.43696125,  3.51280131,
#          3.58864138,  3.66448144,  3.7403215 ,  3.81616157,  3.89200163,
#          3.9678417 ]),
#  <BarContainer object of 100 artists>)
